# %% [markdown]
# # Cloud Masking Test
#
# Test and validate cloud masking algorithm on sample Sentinel-2 data.

# %%
import numpy as np
import matplotlib.pyplot as plt
from src.preprocessing.cloud_mask import CloudMasker

# TODO: Load sample S2 scene with SCL band

# %% [markdown]
# ## Cloud Coverage Analysis

# %%
# TODO: Apply cloud masking
# TODO: Visualize before/after cloud masking
