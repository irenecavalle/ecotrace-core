# %% [markdown]
# # Data Exploration
#
# Exploratory analysis of Sentinel-2 satellite data and supplier locations.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# TODO: Load supplier data and visualize geographic distribution

# %% [markdown]
# ## Supplier Distribution

# %%
# TODO: Plot supplier locations on map
# TODO: Show supplier categories and countries
