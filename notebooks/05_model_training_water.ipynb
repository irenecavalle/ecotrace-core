# %% [markdown]
# # Water Stress Model Training
#
# Train XGBoost water stress classifier.

# %%
import numpy as np
import xgboost as xgb
from src.models.xgboost_water import create_classifier
from src.training.train_xgboost import XGBoostTrainer

# TODO: Load training features and labels

# %% [markdown]
# ## Model Training

# %%
# TODO: Train XGBoost classifier
# TODO: Plot feature importances and confusion matrix
