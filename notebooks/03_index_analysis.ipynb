# %% [markdown]
# # Spectral Index Analysis
#
# Analyze NDVI, NDWI, NDBI, and RE-ChlI time series.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# TODO: Load computed indices for all suppliers

# %% [markdown]
# ## Temporal Patterns

# %%
# TODO: Plot index time series
# TODO: Identify seasonal patterns and anomalies
