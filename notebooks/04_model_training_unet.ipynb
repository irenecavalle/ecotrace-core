# %% [markdown]
# # U-Net Training
#
# Train U-Net deforestation detection model.

# %%
import torch
import pytorch_lightning as pl
from src.models.unet import create_unet
from src.training.train_unet import UNetTrainer

# TODO: Load training data and labels

# %% [markdown]
# ## Model Training

# %%
# TODO: Initialize trainer and run training loop
# TODO: Plot training curves and validation metrics
